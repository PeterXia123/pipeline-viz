# %% [markdown]
# # 03 - Feature Engineering
# Build user-level and order-level features.

# %%
import pandas as pd
from src.features.builder import build_user_features, build_order_features
from src.utils.io_helpers import ensure_dir

# %%
merged = pd.read_csv('data/clean/merged_orders.csv', parse_dates=['order_date'])

# %%
user_features = build_user_features(merged)
order_features = build_order_features(merged)

# %%
ensure_dir('data/features')
user_features.to_csv('data/features/user_features.csv', index=False)
order_features.to_csv('data/features/order_features.csv', index=False)
