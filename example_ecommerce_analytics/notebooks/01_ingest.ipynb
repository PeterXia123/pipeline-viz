# %% [markdown]
# # 01 - Data Ingestion
# Load raw data, validate, write clean copies.

# %%
from src.etl.loaders import load_orders, load_products, load_users
from src.utils.io_helpers import ensure_dir

# %%
orders = load_orders()
products = load_products()
users = load_users()

# %%
ensure_dir('data/clean')
orders.to_csv('data/clean/orders_validated.csv', index=False)
products.to_csv('data/clean/products_validated.csv', index=False)
users.to_csv('data/clean/users_validated.csv', index=False)
