# %% [markdown]
# # 04 - Customer Segmentation
# Segment users based on spending and frequency.

# %%
import pandas as pd
from src.models.segmentation import segment_users
from src.utils.io_helpers import ensure_dir, write_json

# %%
user_features = pd.read_csv('data/features/user_features.csv')

# %%
segmented, centroids = segment_users(user_features)

# %%
ensure_dir('data/models')
segmented.to_csv('data/models/segments.csv', index=False)
write_json(centroids, 'data/models/centroids.json')
