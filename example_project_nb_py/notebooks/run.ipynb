# %%
from src.step_a import prep
from src.step_b import finalize
import pandas as pd
df = pd.read_csv("data/in.csv")
df["c"] = df["a"].map(prep).map(finalize)
df.to_csv("data/out/result.csv", index=False)
