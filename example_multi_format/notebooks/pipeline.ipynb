# %% [markdown]
# # Multi-Format Pipeline
# Demonstrates: CSV → Parquet → CSV + PKL → YAML

# %%
from pipeline import ingest
ingest.run()
# Out:
# Ingested 8 rows

# %%
from pipeline import transform
transform.run()
# Out:
# Summary: 4 products, model saved

# %%
from pipeline import report
report.run()
# Out:
# Report: 4 products, $978.93 revenue
