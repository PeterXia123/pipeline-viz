# %% [markdown]
# # 编排入口：按顺序调用各段 Python

# %%
from pipeline.ingest import merge_sources
from pipeline.transform import split_outputs
from pipeline.report import write_metrics
from lib.helper import pipeline_label

# %%
print("label:", pipeline_label())
merge_sources()
split_outputs()
write_metrics()
# Out:
# label: example_complex_viz
