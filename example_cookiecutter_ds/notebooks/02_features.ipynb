# %% [markdown]
# # 02 — Features
# Engineer columns; write processed table.

# %%
import pandas as pd
from pathlib import Path
from src.ccds_ds.features import engineer_features

Path('data/processed').mkdir(parents=True, exist_ok=True)

df = pd.read_csv('data/interim/merged_orders.csv')
feat = engineer_features(df)
feat.to_csv('data/processed/features.csv', index=False)
