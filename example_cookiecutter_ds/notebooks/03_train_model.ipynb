# %% [markdown]
# # 03 — Train
# Fit a minimal model; persist metrics.

# %%
import pandas as pd
from pathlib import Path
from src.ccds_ds.training import fit_stub

Path('models').mkdir(parents=True, exist_ok=True)

df = pd.read_csv('data/processed/features.csv')
_, metrics = fit_stub(df)
pd.DataFrame([metrics]).to_csv('models/metrics.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/f1/9f6llj2s0js755ndgk44k72c0000gn/T/ipykernel_19899/2331286154.py in <module>
#       1 import pandas as pd
#       2 from pathlib import Path
# ----> 3 from src.ccds_ds.training import fit_stub
#       4
#       5 Path('models').mkdir(parents=True, exist_ok=True)
#
# ModuleNotFoundError: No module named 'src'
