# %%
# manifest 已声明 inputs / outputs；此处真实写出 outputs，便于运行管线后磁盘有产物
from pathlib import Path

root = Path(".").resolve()
aux = root / "data" / "aux"
aux.mkdir(parents=True, exist_ok=True)
stub = (aux / "readme_stub.txt").read_text(encoding="utf-8")
(aux / "derived_note.txt").write_text(
    f"derived from manifest_only (readme_stub lines: {len(stub.splitlines())})\n",
    encoding="utf-8",
)
# Out:
# 50
