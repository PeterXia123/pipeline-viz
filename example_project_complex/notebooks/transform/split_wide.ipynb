# %%
import pandas as pd
import os


os.chdir("/Users/admin/Documents/pipeline-viz/example_project_complex/")

# %%
os.getcwd()
# Out:
# '/Users/admin/Documents/pipeline-viz/example_project_complex'

# %%
df = pd.read_csv("data/staging/merged_orders.csv")

# %%
df.head(5).to_csv("data/out/summary.csv", index=False)
df.to_csv("data/out/detail_wide.csv", index=False)
